# %% [markdown]
# # Ley de enfriamiento de Newton
#
# ### Joshua Briones Andrade

# %%
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Datos de magnetización

# %%
df = pd.read_csv(r'./datos/Magnetizacion_n100.txt', names = ['Temperatura','Magnetización',"Error"], delimiter=r"\s+"
                 ,skiprows=[0])
df.head()
# Out:
#    Temperatura  Magnetización         Error
# 0         0.01            1.0  0.000000e+00
# 1         0.10            1.0  0.000000e+00
# 2         0.20            1.0  0.000000e+00
# 3         0.30            1.0  0.000000e+00
# 4         0.40            1.0  9.624940e-07

# %%
temps = df.iloc[:,0].to_numpy()
mags = df.iloc[:,1].to_numpy()

J = 0.5; K_B=1;
def f(T):
    return 2*(np.tanh(2*J/(K_B*T)))**2-1
Tc = 1.1345873293910556

# %%
TT = 1100
C = TT/(2*Tc)

# %%
plt.plot(C*temps, mags)
plt.vlines(2*C*Tc, 0, 1, colors='r', linestyles='solid', label=r'$T_c=1100\ K$')
plt.vlines(750, 0, 1, colors='orange', linestyles='solid', label=r'$750\ K$')
plt.xlabel(r"Temperatura [K]"); plt.ylabel(r"Magnetización $\langle|m|\rangle$");
plt.legend(); plt.show()

# %% [markdown]
# ### Ley de enfriamiento

# %%
def T(t, Tc, Tm, k):
    temp = (Tc-Tm)*np.exp(-k*t)+Tm
    return temp

# %%
tt = np.array([3.51, 3.23, 4.89, 4.09, 5.39, 3.46, 2.89, 3.04, 4.70, 2.32])
tt.mean(), tt.std()
# Out:
# (3.7520000000000002, 0.9331645085406967)

# %%
tiempo = np.linspace(0,15)
temp0 = T(tiempo, 1200, 298.15, 0.185)
temp1 = T(tiempo, 1200, 298.15, 0.145)
temp2 = T(tiempo, 1200, 298.15, 0.245)

plt.plot(tiempo, temp0)
plt.plot(tiempo, temp1)
plt.plot(tiempo, temp2)

plt.vlines([tt.mean()-tt.std() ,tt.mean(),tt.mean()+tt.std() ], 300, 1200, colors="purple")
plt.plot(tiempo, temp*0+ 750, color="red")

# %% [markdown]
# \begin{equation*}
# k=\frac{\alpha S}{m c_V}=\frac{\alpha S}{\rho V c_H}
# \end{equation*}
